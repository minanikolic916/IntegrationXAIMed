# %%
import torch
import matplotlib.pyplot as plt
from data_ingest import set_data_loaders, set_medmnist_init, load_random_image
from utils import denormalize_image
from model import  load_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import matplotlib.pyplot as plt
#       3 from data_ingest import set_data_loaders, set_medmnist_init, load_random_image
#
# ModuleNotFoundError: No module named 'torch'

# %%
#ucitavanje odgovarajuceg seta i postavljanje data loader-a
DATASET_NAME = "bloodmnist"
data_flag, info, task, DataClass = set_medmnist_init(DATASET_NAME)
train_loader, test_loader = set_data_loaders(data_flag)
# Out:
# Using downloaded and verified file: C:\Users\minan\.medmnist\bloodmnist_224.npz
# Using downloaded and verified file: C:\Users\minan\.medmnist\bloodmnist_224.npz
# Dataset BloodMNIST of size 224 (bloodmnist_224)
#     Number of datapoints: 11959
#     Root location: C:\Users\minan\.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}
#     Number of samples: {'train': 11959, 'val': 1712, 'test': 3421}
# ...

# %%
#ucitavanje modela
resnet_model = load_model("./models/resnet50ft.pth")

# %%
img = load_random_image(test_loader)
reshaped_img = img.permute(1,2,0)
MEAN = torch.tensor([0.5, 0.5, 0.5])
STD = torch.tensor([0.5, 0.5, 0.5])
denormalized_image = (reshaped_img*torch.tensor(STD)) + torch.tensor(MEAN)
plt.imshow(denormalized_image)
# Out:
# C:\Users\minan\AppData\Local\Temp\ipykernel_25468\3014624851.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   denormalized_image = (reshaped_img*torch.tensor(STD)) + torch.tensor(MEAN)

# %%
from xai import get_grad_cam
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 from xai import get_grad_cam
#
# File c:\Users\minan\Downloads\MedicalXAI-master\MedicalXAI-master\source\xai.py:2
#       1 #grad-cam importi
# ----> 2 from pytorch_grad_cam import GradCAM
#       3 from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
#       4 from pytorch_grad_cam.utils.image import show_cam_on_image
#
# File c:\Users\minan\Downloads\MedicalXAI-master\MedicalXAI-master\.venv\lib\site-packages\pytorch_grad_cam\__init__.py:1
# ----> 1 from pytorch_grad_cam.grad_cam import GradCAM
#       2 from pytorch_grad_cam.hirescam import HiResCAM
#       3 from pytorch_grad_cam.grad_cam_elementwise import GradCAMElementWise
#
# File c:\Users\minan\Downloads\MedicalXAI-master\MedicalXAI-master\.venv\lib\site-packages\pytorch_grad_cam\grad_cam.py:2
#       1 import numpy as np
# ...
